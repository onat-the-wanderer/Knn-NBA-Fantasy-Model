# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
 df_ps=pd.read_csv('/Users/onat/Desktop/Knn-NBA-Fantasy-Model/archive/2022-2023 NBA Player Stats - Regular.csv', header=0)

# %%
 df_ps[['Rk','Player','Pos','Age','Tm','G','GS','MP','FG','FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','eFG%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']]=df_ps["Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS"].str.split(';',expand=True)

# %%
 df_ps = df_ps.drop(columns=["Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS","Rk"],axis=1, inplace=False)

# %%
df_ps.head(15)
# Out:
#                       Player Pos Age   Tm   G  GS    MP    FG   FGA   FG%  \
# 0           Precious Achiuwa   C  23  TOR  55  12  20.7   3.6   7.3   485
# 1               Steven Adams   C  29  MEM  42  42    27   3.7   6.3   597
# 2                Bam Adebayo   C  25  MIA  75  75  34.6     8  14.9  0.54
# 3               Ochai Agbaji  SG  22  UTA  59  22  20.5   2.8   6.5   427
# 4               Santi Aldama  PF  22  MEM  77  20  21.8   3.2   6.8  0.47
# 5   Nickeil Alexander-Walker  SG  24  TOT  59   3    15   2.2     5   444
# 6   Nickeil Alexander-Walker  SG  24  UTA  36   3  14.7   2.3   4.7   488
# 7   Nickeil Alexander-Walker  SG  24  MIN  23   0  15.5   2.1   5.4   384
# 8              Grayson Allen  SG  27  MIL  72  70  27.4   3.4   7.7  0.44
# 9              Jarrett Allen   C  24  CLE  68  68  32.6   5.9   9.2   644
# 10             Jose Alvarado  PG  24  NOP  61  10  21.5   3.3     8   411
# 11             Kyle Anderson  PF  29  MIN  69  46  28.4   3.7   7.2   509
# 12     Giannis Antetokounmpo  PF  28  MIL  63  63  32.1  11.2  20.3   553
# 13    Thanasis Antetokounmpo  SF  30  MIL  37   0   5.6   0.5   1.2   435
# 14              Cole Anthony  PG  22  ORL  60   4  25.9   4.6  10.2   454
#
#     ...   FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   ...   702  1.8  4.1     6  0.9  0.6  0.5  1.1  1.9   9.2
# 1   ...   364  5.1  6.5  11.5  2.3  0.9  1.1  1.9  2.3   8.6
# 2   ...   806  2.5  6.7   9.2  3.2  1.2  0.8  2.5  2.8  20.4
# 3   ...   812  0.7  1.3   2.1  1.1  0.3  0.3  0.7  1.7   7.9
# 4   ...  0.75  1.1  3.7   4.8  1.3  0.6  0.6  0.8  1.9     9
# 5   ...   667  0.3  1.5   1.7  1.8  0.5  0.4  0.9  1.5   6.2
# 6   ...   692  0.2  1.4   1.6  2.1  0.7  0.4  1.3  1.6   6.3
# 7   ...   619  0.3  1.5   1.8  1.4  0.3  0.3  0.4  1.3   5.9
# 8   ...   905  0.8  2.4   3.3  2.3  0.9  0.2    1  1.6  10.4
# 9   ...   733  3.3  6.5   9.8  1.7  0.8  1.2  1.4  2.3  14.3
# 10  ...   813  0.5  1.9   2.3    3  1.1  0.2  1.3    2     9
# 11  ...   735    1  4.4   5.3  4.9  1.1  0.9  1.5  2.1   9.4
# 12  ...   645  2.2  9.6  11.8  5.7  0.8  0.8  3.9  3.1  31.1
# 13  ...   0.5  0.4  0.8   1.2  0.4  0.1  0.1  0.3  0.6   1.4
# 14  ...   894  0.8    4   4.8  3.9  0.6  0.5  1.5  2.6    13
#
# [15 rows x 29 columns]

# %%
df_ps_cleaned = df_ps.dropna(how="all")

# %%
df_ps_cleaned[['Age','G','GS','MP','FG','FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','eFG%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']] = df_ps_cleaned[['Age','G','GS','MP','FG','FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','eFG%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']].astype(float)

# %%
df_ps_cleaned['G'].describe()
# Out:
# count    679.000000
# mean      43.338733
# std       24.727306
# min        1.000000
# 25%       22.000000
# 50%       45.000000
# 75%       65.500000
# max       83.000000
# Name: G, dtype: float64

# %%
min_g = df_ps_cleaned['G'].mean()-(df_ps_cleaned['G'].std() * 3)

# %%
min_g
# Out:
# -30.84318460988991

# %%
bin_values = np.arange(start=0, stop=82, step=2)
df_ps_cleaned['G'].hist(bins=bin_values, figsize=[14,6])
# Out:
# <Axes: >

# %%
min_gp = 82
df_filter = df_ps_cleaned[df_ps_cleaned['G'] > min_gp]

# %%
df_filter
# Out:
#            Player Pos   Age   Tm     G    GS    MP   FG   FGA    FG%  ...  \
# 77  Mikal Bridges  SF  26.0  TOT  83.0  83.0  35.7  7.1  15.3  468.0  ...
#
#       FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 77  895.0  1.0  3.4  4.4  3.3  1.1  0.7  1.5  1.9  20.1
#
# [1 rows x 29 columns]
