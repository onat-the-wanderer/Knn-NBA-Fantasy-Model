# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
 df_ps=pd.read_csv('/Users/onat/Desktop/Knn-NBA-Fantasy-Model/archive/2022-2023 NBA Player Stats - Regular.csv', header=0)

# %%
 df_ps[['Rk','Player','Pos','Age','Tm','G','GS','MP','FG','FGA','FG%','3P','3PA','3P%','2P','2PA','2P%','eFG%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS']]=df_ps["Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS"].str.split(';',expand=True)

# %%
 df_ps = df_ps.drop(columns=["Rk;Player;Pos;Age;Tm;G;GS;MP;FG;FGA;FG%;3P;3PA;3P%;2P;2PA;2P%;eFG%;FT;FTA;FT%;ORB;DRB;TRB;AST;STL;BLK;TOV;PF;PTS","Rk"],axis=1, inplace=False)

# %%
df_ps
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  \
# 0    Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3   485  ...   702
# 1        Steven Adams   C  29  MEM  42  42    27  3.7   6.3   597  ...   364
# 2         Bam Adebayo   C  25  MIA  75  75  34.6    8  14.9  0.54  ...   806
# 3        Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5   427  ...   812
# 4        Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  0.47  ...  0.75
# ..                ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 674    Thaddeus Young  PF  34  TOR  54   9  14.7    2   3.7   545  ...   692
# 675        Trae Young  PG  24  ATL  73  73  34.8  8.2    19   429  ...   886
# 676    Omer Yurtseven   C  24  MIA   9   0   9.2  1.8     3   593  ...   833
# 677       Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9   627  ...   686
# 678       Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8   634  ...   697
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0    1.8  4.1     6   0.9  0.6  0.5  1.1  1.9   9.2
# 1    5.1  6.5  11.5   2.3  0.9  1.1  1.9  2.3   8.6
# 2    2.5  6.7   9.2   3.2  1.2  0.8  2.5  2.8  20.4
# 3    0.7  1.3   2.1   1.1  0.3  0.3  0.7  1.7   7.9
# 4    1.1  3.7   4.8   1.3  0.6  0.6  0.8  1.9     9
# ..   ...  ...   ...   ...  ...  ...  ...  ...   ...
# 674  1.3  1.8   3.1   1.4    1  0.1  0.8  1.6   4.4
# 675  0.8  2.2     3  10.2  1.1  0.1  4.1  1.4  26.2
# 676  0.9  1.7   2.6   0.2  0.2  0.2  0.4  1.8   4.4
# 677  1.7  2.6   4.3   0.7  0.2  0.3  0.9  2.2   6.5
# 678  3.1  6.8   9.9     1  0.4  1.3  1.5  2.9  10.8
#
# [679 rows x 29 columns]
